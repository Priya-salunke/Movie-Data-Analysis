# %% [markdown]
# # Exploratory Data Analysis and Visualization Using Python - With Movies Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns   
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('movies_metadata.csv');
df
# Out:
#        Unnamed: 0  adult                              belongs_to_collection  \
# 0               0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1               1  FALSE                                                NaN
# 2               2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3               3  FALSE                                                NaN
# 4               4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...
# ...           ...    ...                                                ...
# 45461       45461  FALSE                                                NaN
# 45462       45462  FALSE                                                NaN
# 45463       45463  FALSE                                                NaN
# 45464       45464  FALSE                                                NaN
# 45465       45465  FALSE                                                NaN
#
# ...

# %%
# import colunmn Ratings

df['Ratings'] = '5star'
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# Read csv file with no header
df = pd.read_csv('movies_metadata.csv',header=None)
df
# Out:
#           0                                                  1         2   \
# 0      adult                              belongs_to_collection    budget
# 1      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2      FALSE                                                NaN  65000000
# 3      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 4      FALSE                                                NaN  16000000
# ...      ...                                                ...       ...
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
# 45466  FALSE                                                NaN         0
#
#                                                       3   \
# ...

# %%
df = pd.read_csv('movies_metadata.csv')
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %%
df.index
# Out:
# RangeIndex(start=0, stop=45466, step=1)

# %%
df.axes
# Out:
# [RangeIndex(start=0, stop=45466, step=1),
#  Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#         'imdb_id', 'original_language', 'original_title', 'overview',
#         'popularity', 'poster_path', 'production_companies',
#         'production_countries', 'release_date', 'revenue', 'runtime',
#         'spoken_languages', 'status', 'tagline', 'title', 'video',
#         'vote_average', 'vote_count'],
#        dtype='object')]

# %%
df.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
df.shape
# Out:
# (45466, 24)

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %%
# access row 2,3,4,5,6...25 and columns adult and budget

df.iloc[2:25,0:3]
# Out:
#     adult                              belongs_to_collection    budget
# 2   FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   FALSE                                                NaN  16000000
# 4   FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5   FALSE                                                NaN  60000000
# 6   FALSE                                                NaN  58000000
# 7   FALSE                                                NaN         0
# 8   FALSE                                                NaN  35000000
# 9   FALSE  {'id': 645, 'name': 'James Bond Collection', '...  58000000
# 10  FALSE                                                NaN  62000000
# 11  FALSE                                                NaN         0
# 12  FALSE  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13  FALSE                                                NaN  44000000
# ...

# %%
df.loc[[1,2,3,4,5,423,11,12,124,20,345,33,24,56,78,90],['adult','budget']]
# Out:
#      adult    budget
# 1    FALSE  65000000
# 2    FALSE         0
# 3    FALSE  16000000
# 4    FALSE         0
# 5    FALSE  60000000
# 423  FALSE  22000000
# 11   FALSE         0
# 12   FALSE         0
# 124  FALSE  17000000
# 20   FALSE  30250000
# 345  FALSE  45000000
# 33   FALSE  30000000
# 24   FALSE   3600000
# 56   FALSE         0
# 78   FALSE  44000000
# 90   FALSE  47000000

# %%
# missing values , drop , sorting, filtering and grouping on dataset

# %%
# Check the count of missing values in each column (Identify missing values)
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df['budget']
# Out:
# 0        30000000
# 1        65000000
# 2               0
# 3        16000000
# 4               0
#            ...
# 45461           0
# 45462           0
# 45463           0
# 45464           0
# 45465           0
# Name: budget, Length: 45466, dtype: object

# %%
# Fill the missing value
df['revenue'].fillna(df['revenue'].mode()[0])
# Out:
# 0        373554033.0
# 1        262797249.0
# 2                0.0
# 3         81452156.0
# 4         76578911.0
#             ...
# 45461            0.0
# 45462            0.0
# 45463            0.0
# 45464            0.0
# 45465            0.0
# Name: revenue, Length: 45466, dtype: float64

# %%
df['overview'].fillna(df['overview'].mode()[0],inplace=True)

# %%
df['overview']
# Out:
# 0        Led by Woody, Andy's toys live happily in his ...
# 1        When siblings Judy and Peter discover an encha...
# 2        A family wedding reignites the ancient feud be...
# 3        Cheated on, mistreated and stepped on, the wom...
# 4        Just when George Banks has recovered from his ...
#                                ...
# 45461          Rising and falling between a man and woman.
# 45462    An artist struggles to finish his work while a...
# 45463    When one of her hits goes wrong, a professiona...
# 45464    In a small town live two brothers, one a minis...
# 45465    50 years after decriminalisation of homosexual...
# Name: overview, Length: 45466, dtype: object

# %%
df['overview'].isna().sum()
# Out:
# 0

# %%
df['revenue'].mean()
# Out:
# 11209348.539265288

# %%
df.isna().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                     0
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %%
df['belongs_to_collection'].fillna(df['belongs_to_collection'].mode()[0],inplace=True)

# %%
df['homepage'].fillna(df['homepage'].mode()[0],inplace=True)

# %%
df['imdb_id'].fillna(df['imdb_id'].mode()[0],inplace=True)

# %%
df['original_language'].fillna(df['original_language'].mode()[0],inplace=True)

# %%
df['popularity'].fillna(df['popularity'].mode()[0],inplace=True)

# %%
df['poster_path'].fillna(df['poster_path'].mode()[0],inplace=True)

# %%
df['production_companies'].fillna(df['production_companies'].mode()[0],inplace=True)

# %%
df['production_countries'].fillna(df['production_countries'].mode()[0],inplace=True)

# %%
df['release_date'].fillna(df['release_date'].mode()[0],inplace=True)

# %%
df['revenue'].fillna(df['revenue'].mode()[0],inplace=True)

# %%
df['runtime'].fillna(df['runtime'].mode()[0],inplace=True)

# %%
df['status'].fillna(df['status'].mode()[0],inplace=True)

# %%
df['tagline'].fillna(df['tagline'].mode()[0],inplace=True)

# %%
df['title'].fillna(df['title'].mode()[0],inplace=True)

# %%
df['video'].fillna(df['video'].mode()[0],inplace=True)

# %%
df['vote_average'].fillna(df['vote_average'].mode()[0],inplace=True)

# %%
df['vote_count'].fillna(df['vote_count'].mode()[0],inplace=True)

# %%
df['spoken_languages'].fillna(df['spoken_languages'].mode()[0],inplace=True)

# %%
df['overview'].fillna(df['overview'].mode()[0],inplace=True)

# %%
df['imdb_id'].isna().sum()
# Out:
# 0

# %%
df['belongs_to_collection'].isna().sum()
# Out:
# 0

# %%
df['homepage'].isna().sum()
# Out:
# 0

# %%
df.isna().sum()
# Out:
# adult                    0
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45462  FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45463  FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45464  FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45465  FALSE  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
#
#                                                   genres  \
# ...

# %%
# Drop the 1st adult column
df.drop('adult',axis=1,inplace=True)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 1      {'id': 415931, 'name': 'The Bowery Boys', 'pos...  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      {'id': 415931, 'name': 'The Bowery Boys', 'pos...  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      {'id': 415931, 'name': 'The Bowery Boys', 'pos...  60000000
# ...                                                  ...       ...
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45463  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45464  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45465  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
#
#                                                   genres  \
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
df = pd.read_csv('movies_metadata.csv')
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
df.drop('adult',axis=1,inplace=True)

# %%
df
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1                                                    NaN  65000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3                                                    NaN  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...                                                  ...       ...
# 45461                                                NaN         0
# 45462                                                NaN         0
# 45463                                                NaN         0
# 45464                                                NaN         0
# 45465                                                NaN         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...

# %%
df.isna().sum()
# Out:
# belongs_to_collection    0
# budget                   0
# genres                   0
# homepage                 0
# id                       0
# imdb_id                  0
# original_language        0
# original_title           0
# overview                 0
# popularity               0
# poster_path              0
# production_companies     0
# production_countries     0
# release_date             0
# revenue                  0
# runtime                  0
# spoken_languages         0
# status                   0
# tagline                  0
# title                    0
# video                    0
# vote_average             0
# vote_count               0
# dtype: int64

# %%
# dropping the 1st row from data.
df.drop(1,axis=0)
# Out:
#                                    belongs_to_collection    budget  \
# 0      {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 2      {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      {'id': 415931, 'name': 'The Bowery Boys', 'pos...  16000000
# 4      {'id': 96871, 'name': 'Father of the Bride Col...         0
# 5      {'id': 415931, 'name': 'The Bowery Boys', 'pos...  60000000
# ...                                                  ...       ...
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45463  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45464  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 45465  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
#
#                                                   genres  \
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# ...

# %% [markdown]
# ## Sorting

# %%
# Sort the df based on budget column in ascending order
df.sort_values('budget',inplace=True)
df
# Out:
#                                    belongs_to_collection  \
# 19730                                           0.065736
# 29503                                           1.931659
# 35587                                           2.185485
# 9403   {'id': 23026, 'name': 'Ghost in the Shell Coll...
# 9404   {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# ...                                                  ...
# 39688  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 34215  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 11609  {'id': 159603, 'name': 'Kidulthood Collection'...
# 39203  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 9247   {'id': 415931, 'name': 'The Bowery Boys', 'pos...
#
#                                  budget  \
# 19730  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 29503  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 35587  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 9403                                  0
# 9404                                  0
# ...

# %%
# Reset the index
df.index = range(0,45466)

# %%
df
# Out:
#                                    belongs_to_collection  \
# 0                                               0.065736
# 1                                               1.931659
# 2                                               2.185485
# 3      {'id': 23026, 'name': 'Ghost in the Shell Coll...
# 4      {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# ...                                                  ...
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45463  {'id': 159603, 'name': 'Kidulthood Collection'...
# 45464  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45465  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
#
#                                  budget  \
# 0      /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 1      /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 2      /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 3                                     0
# 4                                     0
# ...

# %%
df.sort_values('budget',inplace=True)
df
# Out:
#                                    belongs_to_collection  \
# 0                                               0.065736
# 1                                               1.931659
# 2                                               2.185485
# 10579  {'id': 110177, 'name': 'Goal! Collection', 'po...
# 10578  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# ...                                                  ...
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45463  {'id': 159603, 'name': 'Kidulthood Collection'...
# 45464  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45465  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
#
#                                  budget  \
# 0      /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 1      /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 2      /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 10579                                 0
# 10578                                 0
# ...

# %% [markdown]
# ## Filtering

# %%
# # Find out the released movies from dataset
df[df['overview'] == 'Released']
# Out:
#   belongs_to_collection                            budget  \
# 0              0.065736  /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 1              1.931659  /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 2              2.185485  /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
#
#                                               genres  \
# 0  [{'name': 'Carousel Productions', 'id': 11176}...
# 1  [{'name': 'Aniplex', 'id': 2883}, {'name': 'Go...
# 2  [{'name': 'Odyssey Media', 'id': 17161}, {'nam...
#
#                                             homepage          id imdb_id  \
# 0  [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso...  20-08-1997       0
# 1  [{'iso_3166_1': 'US', 'name': 'United States o...  29-09-2012       0
# 2           [{'iso_3166_1': 'CA', 'name': 'Canada'}]  01-01-2014       0
#
#   original_language                            original_title  overview  \
# 0               104  [{'iso_639_1': 'en', 'name': 'English'}]  Released
# 1                68      [{'iso_639_1': 'ja', 'name': '日本語'}]  Released
# ...

# %%
# Find out data for movies which have the original language english.

df[df['original_language']=='en']
# Out:
#                                    belongs_to_collection    budget  \
# 10579  {'id': 110177, 'name': 'Goal! Collection', 'po...         0
# 10578  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 10520  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 10512  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 10513  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# ...                                                  ...       ...
# 45458  {'id': 415931, 'name': 'The Bowery Boys', 'pos...    980385
# 45460  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   9900000
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   9900000
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  99000000
# 45463  {'id': 159603, 'name': 'Kidulthood Collection'...    994000
#
#                                                   genres  \
# 10579                      [{'id': 18, 'name': 'Drama'}]
# ...

# %%
# # Find out the movies which has revenue greater than 100000
df[df['revenue'] >= 100000]
# Out:
#                                    belongs_to_collection    budget  \
# 10667  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 501    {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 22420  {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 4128   {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# 3473   {'id': 415931, 'name': 'The Bowery Boys', 'pos...         0
# ...                                                  ...       ...
# 45459  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   9804690
# 45460  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   9900000
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   9900000
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  99000000
# 45463  {'id': 159603, 'name': 'Kidulthood Collection'...    994000
#
#                                                   genres  \
# 10667  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# ...

# %%
# find out movies which has runtime greater than 500

df[df['runtime']>= 500.0]
# Out:
#                                    belongs_to_collection     budget  \
# 7393   {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 6882   {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 2026   {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 9894   {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 35218  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 32590  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 34165  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 22550  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 22094  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 22100  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 787    {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 19353  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# 30608  {'id': 415931, 'name': 'The Bowery Boys', 'pos...          0
# ...

# %%
# find movies which don't have any genres.
df[df['genres'] == '[]']
# Out:
#                                    belongs_to_collection   budget genres  \
# 10513  {'id': 415931, 'name': 'The Bowery Boys', 'pos...        0     []
# 10634  {'id': 415931, 'name': 'The Bowery Boys', 'pos...        0     []
# 10566  {'id': 415931, 'name': 'The Bowery Boys', 'pos...        0     []
# 10620  {'id': 415931, 'name': 'The Bowery Boys', 'pos...        0     []
# 10653  {'id': 415931, 'name': 'The Bowery Boys', 'pos...        0     []
# ...                                                  ...      ...    ...
# 44713  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  7677765     []
# 44766  {'id': 415931, 'name': 'The Bowery Boys', 'pos...    80000     []
# 44777  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   800000     []
# 44950  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  8000000     []
# 45083  {'id': 415931, 'name': 'The Bowery Boys', 'pos...   850000     []
#
#                                             homepage      id    imdb_id  \
# ...

# %%
# find movies which have the homepage of peanutsmovie.com website
df[df['homepage'] == 'http://www.peanutsmovie.com/']
# Out:
#                                    belongs_to_collection    budget  \
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...  99000000
#
#                                   genres                      homepage  \
# 45462  [{'id': 16, 'name': 'Animation'}]  http://www.peanutsmovie.com/
#
#            id    imdb_id original_language     original_title  \
# 45462  227973  tt2452042                en  The Peanuts Movie
#
#                                                 overview popularity  ...  \
# 45462  Snoopy embarks upon his greatest mission as he...  12.338346  ...
#
#       release_date      revenue runtime  \
# 45462   05-11-2015  246233113.0    88.0
#
#                                spoken_languages    status  \
# 45462  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                                       tagline              title  video  \
# 45462  The story of an underdog. And his dog.  The Peanuts Movie  False
#
#       vote_average vote_count
# ...

# %%
# find movies which don't have the homepage of georgecarlin.com website
df[df['homepage'] != 'http://www.georgecarlin.com']
# Out:
#                                    belongs_to_collection  \
# 0                                               0.065736
# 1                                               1.931659
# 2                                               2.185485
# 10515  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 10516  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# ...                                                  ...
# 45460  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45461  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45462  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
# 45463  {'id': 159603, 'name': 'Kidulthood Collection'...
# 45464  {'id': 415931, 'name': 'The Bowery Boys', 'pos...
#
#                                  budget  \
# 0      /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# 1      /zV8bHuSL6WXoD6FWogP9j4x80bL.jpg
# 2      /zaSf5OG7V8X8gqFvly88zDdRm46.jpg
# 10515                                 0
# 10516                                 0
# ...

# %%
# find movies which don't have the homepage of kidulthood.com website
df[df['homepage'] == 'http://www.kidulthood.co.uk/']
# Out:
#                                    belongs_to_collection  budget  \
# 45463  {'id': 159603, 'name': 'Kidulthood Collection'...  994000
#
#                               genres                      homepage     id  \
# 45463  [{'id': 18, 'name': 'Drama'}]  http://www.kidulthood.co.uk/  13185
#
#          imdb_id original_language original_title  \
# 45463  tt0435680                en     Kidulthood
#
#                                                 overview popularity  ...  \
# 45463  A day in the life of a group of troubled 15-ye...   5.230003  ...
#
#       release_date   revenue runtime  \
# 45463   03-03-2006  165000.0    89.0
#
#                                spoken_languages    status  \
# 45463  [{'iso_639_1': 'en', 'name': 'English'}]  Released
#
#                          tagline       title  video vote_average vote_count
# 45463  Before adulthood comes...  Kidulthood  False          6.2       61.0
#
# [1 rows x 23 columns]

# %% [markdown]
# ## Grouping and Aggregation

# %% [raw]
# 1. Mean
# 2. Min
# 3. Max
# 4. Sum
# 5. median

# %%
# Find min,max,mean,sum,median,count of the budget column

# %%
df['budget'].min()
# Out:
# '/ff9qCepilowshEtG2GYWwzt2bs4.jpg'

# %%
df['budget'].max()
# Out:
# '998000'

# %%
df['budget'].count()
# Out:
# 45466

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  45466 non-null  object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   homepage               45466 non-null  object
#  4   id                     45466 non-null  object
#  5   imdb_id                45466 non-null  object
#  6   original_language      45466 non-null  object
#  7   original_title         45466 non-null  object
#  8   overview               45466 non-null  object
#  9   popularity             45466 non-null  object
#  10  poster_path            45466 non-null  object
#  11  production_companies   45466 non-null  object
#  12  production_countries   45466 non-null  object
#  13  release_date           45466 non-null  object
# ...

# %%
# Find min,max,mean,sum,median,count of the vote_average column

df['vote_average'].min()
# Out:
# 0.0

# %%
df['vote_average'].max()
# Out:
# 10.0

# %%
df['vote_average'].mean()
# Out:
# 5.617465798618747

# %%
df['vote_average'].median()
# Out:
# 6.0

# %%
df['vote_average'].sum()
# Out:
# 255403.69999999998

# %%
df['vote_average'].count()
# Out:
# 45466

# %%
# Find min,max,mean,sum,median,count of the  vote_count column

df['vote_count'].min()
# Out:
# 0.0

# %%
df['vote_count'].max()
# Out:
# 14075.0

# %%
df['vote_count'].median()
# Out:
# 10.0

# %%
df['vote_count'].mean()
# Out:
# 109.88296749219197

# %%
df['vote_count'].sum()
# Out:
# 4995939.0

# %%
df['vote_count'].median()
# Out:
# 10.0

# %%
df['vote_count'].count()
# Out:
# 45466

# %% [markdown]
# ### Group level Aggregate >> group by function

# %%
# Find out genres by the average of vote_count using groupby function
df.groupby('genres')['vote_count'].mean()
# Out:
# genres
# []                                                                                                                                                                                                                  2.944308
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]                                                                                 13.000000
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                                                                                                16.000000
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10752, 'name': 'War'}]                                                                                                                   29.000000
# ...

# %%
# Find out genres by the min , max , sum vote_count using groupby function
df.groupby('genres')['vote_count'].min()
# Out:
# genres
# []                                                                                                                                                                                                                  0.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]                                                                                 13.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                                                                                                14.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10752, 'name': 'War'}]                                                                                                                   29.0
# ...

# %%
df.groupby('genres')['vote_count'].max()
# Out:
# genres
# []                                                                                                                                                                                                                 403.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]                                                                                  13.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                                                                                                 18.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10752, 'name': 'War'}]                                                                                                                    29.0
# ...

# %%
# sum of vote_count by genres 
df.groupby('genres')['vote_count'].sum()
# Out:
# genres
# []                                                                                                                                                                                                                  7190.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]                                                                                    13.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                                                                                                   32.0
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10752, 'name': 'War'}]                                                                                                                      29.0
# ...

# %%
# find homepages link by the average of revenue

df.groupby('homepage')['revenue'].mean()
# Out:
# homepage
# [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'LU', 'name': 'Luxembourg'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]    0.0
# [{'iso_3166_1': 'CA', 'name': 'Canada'}]                                                                                                                                                          0.0
# [{'iso_3166_1': 'US', 'name': 'United States of America'}, {'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                 0.0
# http://009.ph9.jp/                                                                                                                                                                                0.0
# ...

# %%
# find homepage links by the  of sum of runtime

df.groupby('homepage')['runtime'].sum()
# Out:
# homepage
# [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'LU', 'name': 'Luxembourg'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]     90.0
# [{'iso_3166_1': 'CA', 'name': 'Canada'}]                                                                                                                                                           90.0
# [{'iso_3166_1': 'US', 'name': 'United States of America'}, {'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                  90.0
# http://009.ph9.jp/                                                                                                                                                                                103.0
# ...

# %%
# find homepage links by the  of min of runtime

df.groupby('homepage')['runtime'].min()
# Out:
# homepage
# [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'LU', 'name': 'Luxembourg'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]     90.0
# [{'iso_3166_1': 'CA', 'name': 'Canada'}]                                                                                                                                                           90.0
# [{'iso_3166_1': 'US', 'name': 'United States of America'}, {'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                  90.0
# http://009.ph9.jp/                                                                                                                                                                                103.0
# ...

# %% [markdown]
# ## Pandas other functions are applied on my movies dataset

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  45466 non-null  object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   homepage               45466 non-null  object
#  4   id                     45466 non-null  object
#  5   imdb_id                45466 non-null  object
#  6   original_language      45466 non-null  object
#  7   original_title         45466 non-null  object
#  8   overview               45466 non-null  object
#  9   popularity             45466 non-null  object
#  10  poster_path            45466 non-null  object
#  11  production_companies   45466 non-null  object
#  12  production_countries   45466 non-null  object
#  13  release_date           45466 non-null  object
# ...

# %% [markdown]
# ### Value counts function on categorical column

# %%
df['budget'].value_counts()
# Out:
# 0           36573
# 5000000       286
# 10000000      259
# 20000000      243
# 2000000       242
#             ...
# 2489400         1
# 2494400         1
# 25              1
# 250050          1
# 998000          1
# Name: budget, Length: 1226, dtype: int64

# %%
df['genres'].value_counts()
# Out:
# [{'id': 18, 'name': 'Drama'}]                                                                                                       5000
# [{'id': 35, 'name': 'Comedy'}]                                                                                                      3621
# [{'id': 99, 'name': 'Documentary'}]                                                                                                 2723
# []                                                                                                                                  2442
# [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'name': 'Romance'}]                                                                     1301
#                                                                                                                                     ...
# [{'id': 28, 'name': 'Action'}, {'id': 18, 'name': 'Drama'}, {'id': 10402, 'name': 'Music'}, {'id': 53, 'name': 'Thriller'}]            1
# ...

# %%
df['spoken_languages'].value_counts()
# Out:
# [{'iso_639_1': 'en', 'name': 'English'}]                                                                                                                                                                                                            22401
# []                                                                                                                                                                                                                                                   3829
# [{'iso_639_1': 'fr', 'name': 'Français'}]                                                                                                                                                                                                            1853
# ...

# %%
df['production_countries'].value_counts()
# Out:
# [{'iso_3166_1': 'US', 'name': 'United States of America'}]                                                                                                                          17854
# []                                                                                                                                                                                   6282
# [{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]                                                                                                                                     2238
# [{'iso_3166_1': 'FR', 'name': 'France'}]                                                                                                                                             1654
# [{'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                                                              1356
# ...

# %%
df['production_countries'].value_counts().to_dict()
# Out:
# {"[{'iso_3166_1': 'US', 'name': 'United States of America'}]": 17854,
#  '[]': 6282,
#  "[{'iso_3166_1': 'GB', 'name': 'United Kingdom'}]": 2238,
#  "[{'iso_3166_1': 'FR', 'name': 'France'}]": 1654,
#  "[{'iso_3166_1': 'JP', 'name': 'Japan'}]": 1356,
#  "[{'iso_3166_1': 'IT', 'name': 'Italy'}]": 1030,
#  "[{'iso_3166_1': 'CA', 'name': 'Canada'}]": 840,
#  "[{'iso_3166_1': 'DE', 'name': 'Germany'}]": 749,
#  "[{'iso_3166_1': 'IN', 'name': 'India'}]": 735,
#  "[{'iso_3166_1': 'RU', 'name': 'Russia'}]": 735,
#  "[{'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]": 569,
#  "[{'iso_3166_1': 'KR', 'name': 'South Korea'}]": 432,
#  "[{'iso_3166_1': 'ES', 'name': 'Spain'}]": 398,
#  "[{'iso_3166_1': 'HK', 'name': 'Hong Kong'}]": 365,
#  "[{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]": 365,
#  "[{'iso_3166_1': 'AU', 'name': 'Australia'}]": 336,
# ...

# %%
# converting series data into dictionary

df['spoken_languages'].value_counts().to_dict()
# Out:
# {"[{'iso_639_1': 'en', 'name': 'English'}]": 22401,
#  '[]': 3829,
#  "[{'iso_639_1': 'fr', 'name': 'Français'}]": 1853,
#  "[{'iso_639_1': 'ja', 'name': '日本語'}]": 1289,
#  "[{'iso_639_1': 'it', 'name': 'Italiano'}]": 1218,
#  "[{'iso_639_1': 'es', 'name': 'Español'}]": 902,
#  "[{'iso_639_1': 'ru', 'name': 'Pусский'}]": 807,
#  "[{'iso_639_1': 'de', 'name': 'Deutsch'}]": 762,
#  "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'fr', 'name': 'Français'}]": 681,
#  "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'es', 'name': 'Español'}]": 572,
#  "[{'iso_639_1': 'hi', 'name': 'हिन्दी'}]": 481,
#  "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'de', 'name': 'Deutsch'}]": 462,
#  "[{'iso_639_1': 'ko', 'name': '한국어/조선말'}]": 425,
#  "[{'iso_639_1': 'zh', 'name': '普通话'}]": 347,
#  "[{'iso_639_1': 'en', 'name': 'English'}, {'iso_639_1': 'it', 'name': 'Italiano'}]": 326,
#  "[{'iso_639_1': 'sv', 'name': 'svenska'}]": 311,
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 45466 entries, 0 to 45465
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   belongs_to_collection  45466 non-null  object
#  1   budget                 45466 non-null  object
#  2   genres                 45466 non-null  object
#  3   homepage               45466 non-null  object
#  4   id                     45466 non-null  object
#  5   imdb_id                45466 non-null  object
#  6   original_language      45466 non-null  object
#  7   original_title         45466 non-null  object
#  8   overview               45466 non-null  object
#  9   popularity             45466 non-null  object
#  10  poster_path            45466 non-null  object
#  11  production_companies   45466 non-null  object
#  12  production_countries   45466 non-null  object
#  13  release_date           45466 non-null  object
# ...

# %%
## unique and nunique() functions

# %%
df['title'].unique()
# Out:
# array(['Cinderella', 'Goal! III : Taking On The World', '11 Minutes Ago',
#        ..., 'Kidulthood', 'Life Feels Good',
#        'Revolutionary Girl Utena: The Movie'], dtype=object)

# %%
df['production_companies'].unique()
# Out:
# array(['FALSE', '[]',
#        "[{'name': 'Future Film Group', 'id': 777}, {'name': 'Future Films', 'id': 71496}, {'name': 'DRAX audio', 'id': 71497}]",
#        ...,
#        "[{'name': 'Cipher Films', 'id': 6359}, {'name': 'Stealth Films Limited', 'id': 6360}, {'name': 'TMC Films', 'id': 6361}]",
#        "[{'name': 'MFA Filmdistribution', 'id': 910}, {'name': 'Polski Instytut Sztuki Filmowej', 'id': 11240}, {'name': 'Silesia Film (coprodukcja)', 'id': 74832}, {'name': 'Agencja Filmowa Telewizji Polskiej (coprodukcja)', 'id': 74833}]",
#        "[{'name': 'TV Tokyo', 'id': 3034}, {'name': 'Movic', 'id': 3466}, {'name': 'King Record Co.', 'id': 4673}, {'name': 'Shogakukan', 'id': 9149}, {'name': 'J.C.Staff', 'id': 11884}, {'name': 'Star Child Recording', 'id': 21504}, {'name': 'Sega of America', 'id': 22939}, {'name': 'Shôjo Kakumei Utena Production Co.', 'id': 22940}]"],
#       dtype=object)

# %%
df['poster_path'].unique()
# Out:
# array(['Midnight Man', 'Mardock Scramble: The Third Exhaust',
#        'Avalanche Sharks', ..., '/73YPIfNWJOFup8F8gYBA7vUEvp0.jpg',
#        '/v7aPfpcq8gG1Acs08EAkrComAsy.jpg',
#        '/92QbaYRFnMXsJTQcLvHbXGpDAmT.jpg'], dtype=object)

# %%
df['original_title'].unique()
# Out:
# array(["[{'iso_639_1': 'en', 'name': 'English'}]",
#        "[{'iso_639_1': 'ja', 'name': '日本語'}]",
#        'Goal! III : Taking On The World', ..., 'Kidulthood',
#        'Chce się żyć', '少女革命ウテナ アドゥレセンス黙示録'], dtype=object)

# %%
df['poster_path'].nunique()
# Out:
# 45024

# %%
df['popularity'].nunique()
# Out:
# 44176

# %%
df['original_language'].nunique()
# Out:
# 92

# %%
df['homepage'].nunique()
# Out:
# 7673

# %%
df['original_title'].nunique()
# Out:
# 43371

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# Replace the values of the homepage column with something.com

df['original_language'].replace({'en':'english','fa':'french'},inplace=True)

# %%
df['original_language'].replace({'tl':'telugu'},inplace=True)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# replace blank [] with Action/drama/romance string
df['genres'].replace({'[]':'Action/Drama/Romance'},inplace=True)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# replace vote_average[0.0] with the 1000
df['vote_average'].replace({0.0:1000},inplace=True)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# replace vote_count[0.0] with the 100.0
df['vote_count'].replace({0.0:100.0},inplace=True)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# astype : used to change the datatype of any column

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
# change the status datatype object into the int data type.
df['vote_count'] = df['vote_count'].astype(object)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %%
# Take a ration of two columns which will be add in the end of the columns.

df['vote_average/vote_count'] = df['vote_average']/df['vote_count']
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
# Rename the column names using function
df.rename({'original_language':'lang','vote_average':'vote_avg','vote_count':'vote_cnt'},axis=1,inplace=True)

# %%
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %%
#Find out total number of movies who has the vote_cnt >= 200

df[df.vote_cnt >= 200]['vote_cnt'].count()
# Out:
# 3982

# %%
#Find out total number of movies who has the vote_cnt >= 200 and lang='english'

df[(df.vote_cnt>=200)&(df.lang=='english')]['vote_cnt'].count()
# Out:
# 3619

# %%
# find out language wise revenure count of movies

df[df.lang == 'english']['revenue'].count()
# Out:
# 32267

# %%
# grouped the genres by original_title and their count.

df.groupby('genres')['original_title'].count()
# Out:
# genres
# Action/Drama/Romance                                                                                                                                                                                               2442
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}]                                                                                    1
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10751, 'name': 'Family'}]                                                                                                                   2
# [{'id': 10402, 'name': 'Music'}, {'id': 10749, 'name': 'Romance'}, {'id': 10752, 'name': 'War'}]                                                                                                                      1
# ...

# %%
df['adult']
# Out:
# 0        FALSE
# 1        FALSE
# 2        FALSE
# 3        FALSE
# 4        FALSE
#          ...
# 45461    FALSE
# 45462    FALSE
# 45463    FALSE
# 45464    FALSE
# 45465    FALSE
# Name: adult, Length: 45466, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adult                    45466 non-null  object
#  1   belongs_to_collection    4494 non-null   object
#  2   budget                   45466 non-null  object
#  3   genres                   45466 non-null  object
#  4   homepage                 7782 non-null   object
#  5   id                       45466 non-null  object
#  6   imdb_id                  45449 non-null  object
#  7   lang                     45455 non-null  object
#  8   original_title           45466 non-null  object
#  9   overview                 44512 non-null  object
#  10  popularity               45461 non-null  object
#  11  poster_path              45080 non-null  object
#  12  production_companies     45463 non-null  object
#  13  production_countries     45463 non-null  object
# ...

# %%
# grouping the production_countries according to the revenue of movies.
df.groupby('production_countries')['revenue'].count()
# Out:
# production_countries
# 4.3                                                                                                                                                                    0
# 6                                                                                                                                                                      0
# 7                                                                                                                                                                      0
# []                                                                                                                                                                  6282
# [{'iso_3166_1': 'AE', 'name': 'United Arab Emirates'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]       1
# ...

# %%
# grouping the homepage by their vote_avg count
df.groupby('homepage')['vote_avg'].count()
# Out:
# homepage
# [{'iso_3166_1': 'CA', 'name': 'Canada'}, {'iso_3166_1': 'LU', 'name': 'Luxembourg'}, {'iso_3166_1': 'GB', 'name': 'United Kingdom'}, {'iso_3166_1': 'US', 'name': 'United States of America'}]    0
# [{'iso_3166_1': 'CA', 'name': 'Canada'}]                                                                                                                                                          0
# [{'iso_3166_1': 'US', 'name': 'United States of America'}, {'iso_3166_1': 'JP', 'name': 'Japan'}]                                                                                                 0
# http://009.ph9.jp/                                                                                                                                                                                1
# ...

# %%
df['popularity']
# Out:
# 0        21.946943
# 1        17.015539
# 2          11.7129
# 3         3.859495
# 4         8.387519
#            ...
# 45461     0.072051
# 45462     0.178241
# 45463     0.903007
# 45464     0.003503
# 45465     0.163015
# Name: popularity, Length: 45466, dtype: object

# %%
df.groupby('popularity')['runtime'].mean()
# Out:
# popularity
# 0.0                       68.793103
# 1e-06                     79.615385
# 2e-06                     80.000000
# 3e-06                     55.500000
# 4e-06                     92.500000
#                             ...
# 9.914008                  91.000000
# 9.915094                 110.000000
# 9.930139                   0.000000
# 9.968649                  90.000000
# Beware Of Frost Bites           NaN
# Name: runtime, Length: 44176, dtype: float64

# %% [markdown]
# ## Dataframe Joins , read and write df

# %%
A = df[0:5]
A
# Out:
#    adult                              belongs_to_collection    budget  \
# 0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  FALSE                                                NaN  65000000
# 2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  FALSE                                                NaN  16000000
# 4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id     lang  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709  english
# 1                                   NaN   8844  tt0113497  english
# ...

# %%
B = df[10:15]
B
# Out:
#     adult                              belongs_to_collection    budget  \
# 10  FALSE                                                NaN  62000000
# 11  FALSE                                                NaN         0
# 12  FALSE  {'id': 117693, 'name': 'Balto Collection', 'po...         0
# 13  FALSE                                                NaN  44000000
# 14  FALSE                                                NaN  98000000
#
#                                                genres homepage     id  \
# 10  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...      NaN   9087
# 11  [{'id': 35, 'name': 'Comedy'}, {'id': 27, 'nam...      NaN  12110
# 12  [{'id': 10751, 'name': 'Family'}, {'id': 16, '...      NaN  21032
# 13  [{'id': 36, 'name': 'History'}, {'id': 18, 'na...      NaN  10858
# 14  [{'id': 28, 'name': 'Action'}, {'id': 12, 'nam...      NaN   1408
#
#       imdb_id     lang               original_title  \
# 10  tt0112346  english       The American President
# ...

# %%
# concatinating the two tables

pd.concat([A,B],axis=1)
# Out:
#     adult                              belongs_to_collection    budget  \
# 0   FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   FALSE                                                NaN  65000000
# 2   FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   FALSE                                                NaN  16000000
# 4   FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# 10    NaN                                                NaN       NaN
# 11    NaN                                                NaN       NaN
# 12    NaN                                                NaN       NaN
# 13    NaN                                                NaN       NaN
# 14    NaN                                                NaN       NaN
#
#                                                genres  \
# 0   [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# ...

# %%
# inner join on A and B
pd.merge(A,B)
# Out:
# Empty DataFrame
# Columns: [adult, belongs_to_collection, budget, genres, homepage, id, imdb_id, lang, original_title, overview, popularity, poster_path, production_companies, production_countries, release_date, revenue, runtime, spoken_languages, status, tagline, title, video, vote_avg, vote_cnt, vote_average/vote_count]
# Index: []
#
# [0 rows x 25 columns]

# %%
df_new = df.iloc[1:11,[0,2,4]]
df_new
# Out:
#     adult    budget                                      homepage
# 1   FALSE  65000000                                           NaN
# 2   FALSE         0                                           NaN
# 3   FALSE  16000000                                           NaN
# 4   FALSE         0                                           NaN
# 5   FALSE  60000000                                           NaN
# 6   FALSE  58000000                                           NaN
# 7   FALSE         0                                           NaN
# 8   FALSE  35000000                                           NaN
# 9   FALSE  58000000  http://www.mgm.com/view/movie/757/Goldeneye/
# 10  FALSE  62000000                                           NaN

# %%
# creating new dataframe 
df_new = df.iloc[1:11,[1,3,5,7,9,11]]
df_new
# Out:
#                                 belongs_to_collection  \
# 1                                                 NaN
# 2   {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3                                                 NaN
# 4   {'id': 96871, 'name': 'Father of the Bride Col...
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9   {'id': 645, 'name': 'James Bond Collection', '...
# 10                                                NaN
#
#                                                genres     id     lang  \
# 1   [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...   8844  english
# 2   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...  15602  english
# 3   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...  31357  english
# 4                      [{'id': 35, 'name': 'Comedy'}]  11862  english
# ...

# %%
df.to_csv('movies_metadata.csv')
df
# Out:
#        adult                              belongs_to_collection    budget  \
# 0      FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1      FALSE                                                NaN  65000000
# 2      FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3      FALSE                                                NaN  16000000
# 4      FALSE  {'id': 96871, 'name': 'Father of the Bride Col...         0
# ...      ...                                                ...       ...
# 45461  FALSE                                                NaN         0
# 45462  FALSE                                                NaN         0
# 45463  FALSE                                                NaN         0
# 45464  FALSE                                                NaN         0
# 45465  FALSE                                                NaN         0
#
#                                                   genres  \
# ...

# %% [markdown]
# # Data Visualization

# %%
# import libraries (data manipulation,data visualization and warnings)

import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [raw]
# -0.5 to +0.5 >> Symmetrical distribution
# -1 to -0.5 >> Negative skewed distribution
# -1 > skew  >> Highly negative skewed distribution (-1.2,-1.5)
#
# 0.5 to 1.0 >> Positive skewed distribution
# skew > 1.0 >> Highly positive skewed distribtion(1.3,1.6)

# %%
# checking the skewness of continouse columns using skew() function

df['vote_avg'].skew()
# Out:
# 3.4976891821535308

# %% [markdown]
# # univariate analysis

# %% [markdown]
# ## continuous columns

# %%
## distribution plot

sns.distplot(df['vote_avg'])
# Out:
# <Axes: xlabel='vote_avg', ylabel='Density'>

# %%
sns.distplot(df['revenue'])
# Out:
# <Axes: xlabel='revenue', ylabel='Density'>

# %%
sns.distplot(df['runtime'])
# Out:
# <Axes: xlabel='runtime', ylabel='Density'>

# %%
sns.distplot(df['vote_average/vote_count'])
# Out:
# <Axes: xlabel='vote_average/vote_count', ylabel='Density'>

# %%
# Transformation techniques
1. squareroot 
2. log
3. cuberoot
4. reciprocal

# %% [markdown]
# ## Transformation techniques

# %%
sns.distplot(np.sqrt(df['runtime']))
# Out:
# <Axes: xlabel='runtime', ylabel='Density'>

# %%
sns.distplot(np.cbrt(df['runtime']))
# Out:
# <Axes: xlabel='runtime', ylabel='Density'>

# %%
sns.distplot(1/(df['vote_cnt']))
# Out:
# <Axes: xlabel='vote_cnt', ylabel='Density'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adult                    45466 non-null  object
#  1   belongs_to_collection    4494 non-null   object
#  2   budget                   45466 non-null  object
#  3   genres                   45466 non-null  object
#  4   homepage                 7782 non-null   object
#  5   id                       45466 non-null  object
#  6   imdb_id                  45449 non-null  object
#  7   lang                     45455 non-null  object
#  8   original_title           45466 non-null  object
#  9   overview                 44512 non-null  object
#  10  popularity               45461 non-null  object
#  11  poster_path              45080 non-null  object
#  12  production_companies     45463 non-null  object
#  13  production_countries     45463 non-null  object
# ...

# %%
df['revenue'].skew()
# Out:
# 12.265982911711072

# %%
df['revenue'].mean()
# Out:
# 11209348.539265288

# %%
df['revenue'].median()
# Out:
# 0.0

# %%
df['vote_cnt'].skew()
# Out:
# 10.464410637745342

# %%
df['vote_cnt'].mean()
# Out:
# 116.27437307523097

# %%
df['vote_cnt'].median()
# Out:
# 13.0

# %%
sns.distplot(df['vote_cnt'])
# Out:
# <Axes: xlabel='vote_cnt', ylabel='Density'>

# %%
sns.distplot(df['runtime'])
# Out:
# <Axes: xlabel='runtime', ylabel='Density'>

# %%
df['runtime'].skew()
# Out:
# 4.465957935359167

# %%
df['runtime'].mean()
# Out:
# 94.12819945578833

# %%
df['runtime'].median()
# Out:
# 95.0

# %% [markdown]
# ## Subplots

# %%
# Make a subplot having 4 distribution plots of revenue,runtime,vote_avg,vote_cnt columns

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.distplot(df['revenue'])

plt.subplot(2,2,2)
sns.distplot(df['runtime'])

plt.subplot(2,2,3)
sns.distplot(df['vote_cnt'])

plt.subplot(2,2,4)
sns.distplot(df['vote_avg'])
# Out:
# <Axes: xlabel='vote_avg', ylabel='Density'>

# %%
# Make a subplot having 4 distribution plots of revenue,runtime,vote_avg,vote_cnt columns using transformation techniques.

plt.figure(figsize=(15,10))

plt.subplot(2,2,1)
sns.distplot(np.sqrt(df['revenue']))

plt.subplot(2,2,2)
sns.distplot(np.cbrt(df['runtime']))

plt.subplot(2,2,3)
sns.distplot(1/df['vote_cnt'])

plt.subplot(2,2,4)
sns.distplot(1/df['vote_avg'])
# Out:
# <Axes: xlabel='vote_avg', ylabel='Density'>

# %% [markdown]
# ## Categorical columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 25 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   adult                    45466 non-null  object
#  1   belongs_to_collection    4494 non-null   object
#  2   budget                   45466 non-null  object
#  3   genres                   45466 non-null  object
#  4   homepage                 7782 non-null   object
#  5   id                       45466 non-null  object
#  6   imdb_id                  45449 non-null  object
#  7   lang                     45455 non-null  object
#  8   original_title           45466 non-null  object
#  9   overview                 44512 non-null  object
#  10  popularity               45461 non-null  object
#  11  poster_path              45080 non-null  object
#  12  production_companies     45463 non-null  object
#  13  production_countries     45463 non-null  object
# ...

# %%
df['original_title'].value_counts()
# Out:
# Hamlet                  8
# Alice in Wonderland     8
# The Three Musketeers    7
# Les Misérables          7
# Cinderella              7
#                        ..
# Ankur                   1
# For Neda                1
# La Bataille du rail     1
# 거미숲                     1
# Queerama                1
# Name: original_title, Length: 43371, dtype: int64

# %%
# Plot countplot of original_title column (Visual representation of value counts)
sns.countplot(data=df,x='original_title')

# %%
df['lang'].value_counts()
# Out:
# english    32269
# fr          2438
# it          1529
# ja          1350
# de          1080
#            ...
# zu             1
# qu             1
# 104            1
# la             1
# si             1
# Name: lang, Length: 92, dtype: int64

# %%
df
# Out:
#        Unnamed: 0  adult                              belongs_to_collection  \
# 0               0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1               1  FALSE                                                NaN
# 2               2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3               3  FALSE                                                NaN
# 4               4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...
# ...           ...    ...                                                ...
# 45461       45461  FALSE                                                NaN
# 45462       45462  FALSE                                                NaN
# 45463       45463  FALSE                                                NaN
# 45464       45464  FALSE                                                NaN
# 45465       45465  FALSE                                                NaN
#
# ...

# %%
df.drop([20,21,22],inplace=True)

# %%
df.drop(df.index[23:45466],inplace=True)

# %%
df
# Out:
#     Unnamed: 0  adult                              belongs_to_collection  \
# 0            0  FALSE  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1            1  FALSE                                                NaN
# 2            2  FALSE  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3            3  FALSE                                                NaN
# 4            4  FALSE  {'id': 96871, 'name': 'Father of the Bride Col...
# 5            5  FALSE                                                NaN
# 6            6  FALSE                                                NaN
# 7            7  FALSE                                                NaN
# 8            8  FALSE                                                NaN
# 9            9  FALSE  {'id': 645, 'name': 'James Bond Collection', '...
# 10          10  FALSE                                                NaN
# 11          11  FALSE                                                NaN
# ...

# %%
plt.figure(figsize=(15,7))
sns.countplot(data=df,x='homepage')
# Out:
# <Axes: xlabel='homepage', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x='budget')
# Out:
# <Axes: xlabel='budget', ylabel='count'>

# %%
plt.figure(figsize=(15,10))
sns.countplot(data=df,x='id')
# Out:
# <Axes: xlabel='id', ylabel='count'>

# %%
plt.figure(figsize=(26,10))
sns.countplot(data=df,x='title')
# Out:
# <Axes: xlabel='title', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df,x='genres')
# Out:
# <Axes: xlabel='genres', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 25
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23 non-null     int64
#  1   adult                    23 non-null     object
#  2   belongs_to_collection    6 non-null      object
#  3   budget                   23 non-null     object
#  4   genres                   23 non-null     object
#  5   homepage                 3 non-null      object
#  6   id                       23 non-null     object
#  7   imdb_id                  23 non-null     object
#  8   lang                     23 non-null     object
#  9   original_title           23 non-null     object
#  10  overview                 23 non-null     object
#  11  popularity               23 non-null     object
#  12  poster_path              23 non-null     object
#  13  production_companies     23 non-null     object
# ...

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df,x='production_countries')
# Out:
# <Axes: xlabel='production_countries', ylabel='count'>

# %%
plt.figure(figsize=(20,10))
sns.countplot(data=df,x='homepage',hue='revenue')
# Out:
# <Axes: xlabel='homepage', ylabel='count'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 25
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23 non-null     int64
#  1   adult                    23 non-null     object
#  2   belongs_to_collection    6 non-null      object
#  3   budget                   23 non-null     object
#  4   genres                   23 non-null     object
#  5   homepage                 3 non-null      object
#  6   id                       23 non-null     object
#  7   imdb_id                  23 non-null     object
#  8   lang                     23 non-null     object
#  9   original_title           23 non-null     object
#  10  overview                 23 non-null     object
#  11  popularity               23 non-null     object
#  12  poster_path              23 non-null     object
#  13  production_companies     23 non-null     object
# ...

# %%
plt.figure(figsize=(50,50))

plt.subplot(3,3,1)
sns.distplot(df['vote_cnt'])

plt.subplot(3,3,2)
sns.distplot(df['vote_avg'])

plt.subplot(3,3,3)
sns.countplot(data=df,x='production_companies')

plt.subplot(3,3,4)
sns.countplot(data=df,x='popularity')

plt.subplot(3,3,5)
sns.countplot(data=df,x='overview')

plt.subplot(3,3,6)
sns.distplot(df['revenue'])

plt.subplot(3,3,7)
sns.distplot(df['runtime'])

plt.subplot(3,3,8)
sns.countplot(data=df,x='belongs_to_collection')

plt.subplot(3,3,9)
sns.countplot(data=df,x='title')
# Out:
# <Axes: xlabel='title', ylabel='count'>

# %% [markdown]
# ## Continuous vs Continuous

# %% [markdown]
# # Bivariate Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 25
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23 non-null     int64
#  1   adult                    23 non-null     object
#  2   belongs_to_collection    6 non-null      object
#  3   budget                   23 non-null     object
#  4   genres                   23 non-null     object
#  5   homepage                 3 non-null      object
#  6   id                       23 non-null     object
#  7   imdb_id                  23 non-null     object
#  8   lang                     23 non-null     object
#  9   original_title           23 non-null     object
#  10  overview                 23 non-null     object
#  11  popularity               23 non-null     object
#  12  poster_path              23 non-null     object
#  13  production_companies     23 non-null     object
# ...

# %%
sns.scatterplot(data=df,x='vote_avg',y='id')
# Out:
# <Axes: xlabel='vote_avg', ylabel='id'>

# %%
sns.scatterplot(data=df,x='revenue',y='title')
# Out:
# <Axes: xlabel='revenue', ylabel='title'>

# %%
sns.scatterplot(data=df,x='runtime',y='poster_path')
# Out:
# <Axes: xlabel='runtime', ylabel='poster_path'>

# %%
sns.scatterplot(data=df,x='revenue',y='homepage')
# Out:
# <Axes: xlabel='revenue', ylabel='homepage'>

# %%
plt.figure(figsize=(15,8))
sns.scatterplot(data=df,x='id',y='id')
# Out:
# <Axes: xlabel='id', ylabel='id'>

# %%
df.corr()
# Out:
#                          Unnamed: 0   revenue   runtime  vote_avg  vote_cnt  \
# Unnamed: 0                 1.000000 -0.387153  0.080522  0.015368 -0.404802
# revenue                   -0.387153  1.000000  0.001956  0.418263  0.804204
# runtime                    0.080522  0.001956  1.000000  0.441758 -0.109963
# vote_avg                   0.015368  0.418263  0.441758  1.000000  0.540152
# vote_cnt                  -0.404802  0.804204 -0.109963  0.540152  1.000000
# vote_average/vote_count    0.097292 -0.430693  0.141657 -0.177468 -0.412931
#
#                          vote_average/vote_count
# Unnamed: 0                              0.097292
# revenue                                -0.430693
# runtime                                 0.141657
# vote_avg                               -0.177468
# vote_cnt                               -0.412931
# vote_average/vote_count                 1.000000

# %%
sns.scatterplot(data=df,x='vote_avg',y='revenue')
# Out:
# <Axes: xlabel='vote_avg', ylabel='revenue'>

# %%
sns.scatterplot(data=df,x='vote_cnt',y='runtime')
# Out:
# <Axes: xlabel='vote_cnt', ylabel='runtime'>

# %%
# use the numpy function to find the coefficient of correlation between vote_Avg abd vote_cnt
np.corrcoef(df['vote_avg'],df['vote_cnt'])
# Out:
# array([[1.        , 0.54015189],
#        [0.54015189, 1.        ]])

# %%
np.corrcoef(df['runtime'],df['revenue'])
# Out:
# array([[1.        , 0.00195645],
#        [0.00195645, 1.        ]])

# %% [markdown]
# ## Continuous vs Categorical / Categorical vs Continous¶

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 23 entries, 0 to 25
# Data columns (total 26 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Unnamed: 0               23 non-null     int64
#  1   adult                    23 non-null     object
#  2   belongs_to_collection    6 non-null      object
#  3   budget                   23 non-null     object
#  4   genres                   23 non-null     object
#  5   homepage                 3 non-null      object
#  6   id                       23 non-null     object
#  7   imdb_id                  23 non-null     object
#  8   lang                     23 non-null     object
#  9   original_title           23 non-null     object
#  10  overview                 23 non-null     object
#  11  popularity               23 non-null     object
#  12  poster_path              23 non-null     object
#  13  production_companies     23 non-null     object
# ...

# %%
# boxplot of vote_avg vs spoken_languages
sns.boxplot(data=df,x='vote_avg',y='spoken_languages')
# Out:
# <Axes: xlabel='vote_avg', ylabel='spoken_languages'>

# %%
sns.boxplot(data=df,x='revenue',y='status')
# Out:
# <Axes: xlabel='revenue', ylabel='status'>

# %%
sns.boxplot(data=df,x='revenue',y='budget')
# Out:
# <Axes: xlabel='revenue', ylabel='budget'>

# %%
sns.boxplot(data=df,x='runtime',y='budget')
# Out:
# <Axes: xlabel='runtime', ylabel='budget'>

# %%
sns.boxplot(data=df,x='revenue',y='adult')
# Out:
# <Axes: xlabel='revenue', ylabel='adult'>

# %%
sns.boxplot(data=df,x='vote_avg',y='budget')
# Out:
# <Axes: xlabel='vote_avg', ylabel='budget'>

# %%
sns.boxplot(data=df,x='revenue',y='genres')
# Out:
# <Axes: xlabel='revenue', ylabel='genres'>

# %%
sns.boxplot(data=df,x='runtime',y='popularity')
# Out:
# <Axes: xlabel='runtime', ylabel='popularity'>

# %% [markdown]
# ## categorical vs categorical

# %%
# countplot with hue

# %%
sns.countplot(data=df,x='revenue',hue='budget')
# Out:
# <Axes: xlabel='revenue', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df,x='vote_avg',hue='homepage')
# Out:
# <Axes: xlabel='vote_avg', ylabel='count'>

# %%
plt.figure(figsize=(15,6))
sns.countplot(data=df,x='runtime',hue='budget')
# Out:
# <Axes: xlabel='runtime', ylabel='count'>

# %% [markdown]
# ## multivariate analysis

# %%
sns.heatmap(df.corr(),annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df.corr())
